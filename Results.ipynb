# %%
import pandas as pd 
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## **Original Dataset (Entertainment Category)**

# %%
sentiment_df_entertainment = pd.read_csv('/content/gdrive/My Drive/MIProject/LRmodel/sentiment_entertainment.csv')
train_df_entertainment = sentiment_df_entertainment.loc[(sentiment_df_entertainment['articles_sentiment'] == sentiment_df_entertainment['summary_sentiment'])]
test_df_entertainment = sentiment_df_entertainment.loc[(sentiment_df_entertainment['articles_sentiment'] != sentiment_df_entertainment['summary_sentiment'])]

# %%
sentiment_df_entertainment
# Out:
#      Unnamed: 0                                           articles  \
# 0          1329  Comic Morris returns with sitcom\n\nComedian C...
# 1          1330  BBC denies Blackadder TV comeback\n\nThe BBC h...
# 2          1331  New media battle for Bafta awards\n\nThe BBC l...
# 3          1332  UK Directors Guild nominees named\n\nMartin Sc...
# 4          1333  Franz Ferdinand's art school lesson\n\nScottis...
# ..          ...                                                ...
# 381        1710  US charity anthem is re-released\n\nWe Are The...
# 382        1711  U2 to play at Grammy awards show\n\nIrish rock...
# 383        1712  Ray DVD beats box office takings\n\nOscar-nomi...
# 384        1713  The Producers scoops stage awards\n\nThe Produ...
# 385        1714  Tautou 'to star in Da Vinci film'\n\nFrench ac...
#
#                                              summaries       category  \
# 0    Comedian Chris Morris, who created controversi...  entertainment
# 1    The BBC has said there are no plans in the pip...  entertainment
# 2    ITV's Great British Spelling Test takes on the...  entertainment
# 3    Mike Leigh's Vera Drake is among the nominees ...  entertainment
# 4    The buzz about the band soon spread around the...  entertainment
# ..                                                 ...            ...
# 381  It has been re-issued as part of a two-disc DV...  entertainment
# 382  Irish rock band U2 are to play live at the Gra...  entertainment
# 383  Ray has been nominated in six Oscar categories...  entertainment
# 384  - Best lighting design - His Dark Materials de...  entertainment
# 385  French actress Audrey Tautou, star of hit film...  entertainment
#
#      articles_sentiment  summary_sentiment
# 0                     1                  1
# 1                     0                  0
# 2                     1                  1
# 3                     1                  1
# 4                     1                  1
# ..                  ...                ...
# 381                   1                  1
# 382                   1                  1
# 383                   1                  1
# 384                   1                  1
# 385                   1                  1
#
# [386 rows x 6 columns]

# %%
train_df_entertainment
# Out:
#      Unnamed: 0                                           articles  \
# 0          1329  Comic Morris returns with sitcom\n\nComedian C...
# 1          1330  BBC denies Blackadder TV comeback\n\nThe BBC h...
# 2          1331  New media battle for Bafta awards\n\nThe BBC l...
# 3          1332  UK Directors Guild nominees named\n\nMartin Sc...
# 4          1333  Franz Ferdinand's art school lesson\n\nScottis...
# ..          ...                                                ...
# 381        1710  US charity anthem is re-released\n\nWe Are The...
# 382        1711  U2 to play at Grammy awards show\n\nIrish rock...
# 383        1712  Ray DVD beats box office takings\n\nOscar-nomi...
# 384        1713  The Producers scoops stage awards\n\nThe Produ...
# 385        1714  Tautou 'to star in Da Vinci film'\n\nFrench ac...
#
#                                              summaries       category  \
# 0    Comedian Chris Morris, who created controversi...  entertainment
# 1    The BBC has said there are no plans in the pip...  entertainment
# 2    ITV's Great British Spelling Test takes on the...  entertainment
# 3    Mike Leigh's Vera Drake is among the nominees ...  entertainment
# 4    The buzz about the band soon spread around the...  entertainment
# ..                                                 ...            ...
# 381  It has been re-issued as part of a two-disc DV...  entertainment
# 382  Irish rock band U2 are to play live at the Gra...  entertainment
# 383  Ray has been nominated in six Oscar categories...  entertainment
# 384  - Best lighting design - His Dark Materials de...  entertainment
# 385  French actress Audrey Tautou, star of hit film...  entertainment
#
#      articles_sentiment  summary_sentiment
# 0                     1                  1
# 1                     0                  0
# 2                     1                  1
# 3                     1                  1
# 4                     1                  1
# ..                  ...                ...
# 381                   1                  1
# 382                   1                  1
# 383                   1                  1
# 384                   1                  1
# 385                   1                  1
#
# [339 rows x 6 columns]

# %% [markdown]
# ## **Tarined T5 Model**

# %%
# !pip install pytorch_lightning
# !pip install transformers

# %%
import json
import torch
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint 
from pytorch_lightning.loggers import TensorBoardLogger 
from sklearn.model_selection import train_test_split
from termcolor import colored 
import textwrap

from transformers import (
    AdamW,
    T5ForConditionalGeneration, 
    T5TokenizerFast as T5Tokenizer
)

from tqdm.auto import tqdm

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5_fast.py:166: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,

# %%
class NewsSummaryModel(pl.LightningModule):
    def __init__(self):

      super().__init__()

      self.model = T5ForConditionalGeneration.from_pretrained('t5-base', return_dict=True)

    def forward(self, input_ids, attention_mask, decoder_attention_mask, labels=None):
      output = self.model(
      input_ids,
      attention_mask=attention_mask,
      labels=labels,
      decoder_attention_mask=decoder_attention_mask
      )
      return output.loss, output.logits

    def training_step(self, batch, batch_size): 
      input_ids = batch['text_input_ids']
      attention_mask = batch['text_attention_mask']
      labels = batch['labels']
      labels_attention_mask = batch['labels_attention_mask']

      loss, output = self(
          input_ids = input_ids, 
          attention_mask = attention_mask, 
          decoder_attention_mask = labels_attention_mask, 
          labels = labels
      )

      self.log("test_loss", loss, prog_bar = True, logger = True)
      return loss

    def validation_step(self, batch, batch_size):
        input_ids = batch['text_input_ids']
        attention_mask = batch['text_attention_mask']
        labels = batch['labels']
        labels_attention_mask = batch['labels_attention_mask']

        loss, outputs = self(
            input_ids = input_ids,
            attention_mask = attention_mask,
            decoder_attention_mask = labels_attention_mask,
            labels = labels
        )

        self.log("val_loss", loss, prog_bar=True, logger=True)
        return loss

    def test_step(self, batch, batch_size): 
        input_ids = batch['text_input_ids']
        attention_mask = batch['text_attention_mask'] 
        labels = batch['labels'] 
        labels_attention_mask = batch['labels_attention_mask']

        loss, outputs = self(
            input_ids = input_ids,
            attention_mask = attention_mask,
            decoder_attention_mask=labels_attention_mask, 
            labels = labels
        )
        self.log('test loss', loss, prog_bar=True, logger=True)
        return loss

    def configure_optimizers(self):
        return AdamW(self.parameters(), lr=0.0001)

# %%
trained_model = NewsSummaryModel.load_from_checkpoint(
    '/content/gdrive/My Drive/MIProject/T5model/best-checkpoint.ckpt'
)
trained_model.freeze()
# Out:
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
def summarizeText(text):
  text_encoding = tokenizer(
      text,
      max_length = 512,
      padding = 'max_length',
      truncation = True,
      return_attention_mask = True,
      add_special_tokens = True,
      return_tensors = 'pt'
  )

  generated_ids = trained_model.model.generate(
      input_ids = text_encoding['input_ids'],
      attention_mask = text_encoding['attention_mask'],
      max_length = 150,
      num_beams = 2,
      repetition_penalty = 2.5,
      length_penalty = 1.0,
      early_stopping = True
  )

  preds = [
      tokenizer.decode(gen_id, skip_special_tokens = True, clean_up_tokenization_spaces=True)
      for gen_id in generated_ids
  ]

  return "".join(preds)

# %%
# !pip install gradio

# %%
import gradio as gr
def question_answer(context):
    return summarizeText(context)

gr.Interface(fn=question_answer, inputs="text", outputs="text").launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %% [markdown]
# ## **LR For Sentiment**

# %%
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import pickle
import re

# %%
def load_models():
    
    # Load the vectoriser.
    file = open('/content/gdrive/My Drive/MIProject/Models/vectoriser-ngram-(1,2).pickle', 'rb')
    vectoriser = pickle.load(file)
    file.close()
    # Load the LR Model.
    file = open('/content/gdrive/My Drive/MIProject/Models/Sentiment-LR.pickle', 'rb')
    LRmodel = pickle.load(file)
    file.close()
    
    return vectoriser, LRmodel

# %%
vectorizer, LRmodel = load_models()

# %%
def _preprocess_for_sentiment(textdata):
    processedText = []
    
    # Create Lemmatizer and Stemmer.
    wordLemm = WordNetLemmatizer()
    
    # Defining regex patterns.
    urlPattern        = r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)"
    userPattern       = '@[^\s]+'
    alphaPattern      = "[^a-zA-Z0-9]"
    sequencePattern   = r"(.)\1\1+"
    seqReplacePattern = r"\1\1"
    
    for tweet in textdata:
        tweet = tweet.lower()
        
        # Replace all URls with 'URL'
        tweet = re.sub(urlPattern,' URL',tweet)
        # Replace all emojis.    
        # Replace @USERNAME to 'USER'.
        tweet = re.sub(userPattern,' USER', tweet)        
        # Replace all non alphabets.
        tweet = re.sub(alphaPattern, " ", tweet)
        # Replace 3 or more consecutive letters by 2 letter.
        tweet = re.sub(sequencePattern, seqReplacePattern, tweet)

        tweetwords = ''
        for word in tweet.split():
            # Checking if the word is a stopword.
            #if word not in stopwordlist:
            if len(word)>1:
                # Lemmatizing the word.
                word = wordLemm.lemmatize(word)
                tweetwords += (word+' ')
            
        processedText.append(tweetwords)
        
    return processedText

# %%
def _predict(vectoriser, model, data):
    # Predict the sentiment
    text = []
    text.append(data)
    textdata = vectoriser.transform(_preprocess_for_sentiment(text))
    sentiment = model.predict(textdata)
    return sentiment[0]

# %%
import gradio as gr
def question_answer(context):
    return _predict(vectorizer, LRmodel, context)

gr.Interface(fn=question_answer, inputs="text", outputs="text").launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %% [markdown]
# ## **Tarined T5 Model on the test data**

# %%
summary_df_entertainment = pd.read_csv('/content/gdrive/My Drive/MIProject/T5model/test_entertainment.csv')

# %%
summary_sentiment_df_entertainment = pd.read_csv('/content/gdrive/My Drive/MIProject/T5model/test_entertainment_sentiment.csv')

# %%
columns_titles = ['articles', 'articles_sentiment', 'summaries', 'summary_sentiment', 'pred_summary_pt', 'pred_summary_sentiment']
results = summary_sentiment_df_entertainment.reindex(columns=columns_titles)

# %%
results
# Out:
#                                              articles  articles_sentiment  \
# 0   iTunes now selling Band Aid song\n\nIpod owner...                   1
# 1   Briton wins short film Oscar\n\nThree of the f...                   0
# 2   Britney attacks 'false tabloids'\n\nPop star B...                   0
# 3   Prince crowned 'top music earner'\n\nPrince ea...                   1
# 4   No UK premiere for Rings musical\n\nThe produc...                   1
# 5   Prince crowned 'top music earner'\n\nPrince ea...                   1
# 6   Robots march to US cinema summit\n\nAnimated m...                   1
# 7   Label withdraws McFadden's video\n\nThe new vi...                   1
# 8   Byrds producer Melcher dies at 62\n\nRecord pr...                   1
# 9   Row threatens Hendrix museum plan\n\nProposals...                   0
# 10  UK debut for Kevin Spacey movie\n\nHollywood s...                   0
# 11  Oscars race enters final furlong\n\nThe race f...                   1
# 12  No jail for singer Courtney Love\n\nSinger Cou...                   0
# 13  Snow Patrol bassist exits group\n\nSnow Patrol...                   0
# 14  Fox 'too reliant on reality TV'\n\nThe head of...                   0
# 15  Ring of Fire hit co-writer dies\n\nMerle Kilgo...                   0
# 16  Court halts Mark Morrison album\n\nPremiership...                   0
# 17  Fears raised over ballet future\n\nFewer child...                   0
# 18  Oscars steer clear of controversy\n\nThe Oscar...                   0
# 19  Public show for Reynolds portrait\n\nSir Joshu...                   0
# 20  Rocker Doherty in on-stage fight\n\nRock singe...                   0
# 21  Baghdad Blogger on big screen\n\nA film based ...                   0
# 22  Rapper 50 Cent ends protege feud\n\nRapper 50 ...                   0
# 23  T in the Park sells out in days\n\nTickets for...                   1
# 24  Dutch watch Van Gogh's last film\n\nThe last f...                   0
# 25  Elvis 'set for chart hat-trick'\n\nThe late US...                   1
# 26  US actor Ossie Davis found dead\n\nUS actor Os...                   0
# 27  DVD review: Spider-Man 2\n\nIt's a universal r...                   0
# 28  Hillbillies singer Scoggins dies\n\nCountry an...                   1
# 29  Springer criticises Opera musical\n\nTalk show...                   1
# 30  Fockers retain film chart crown\n\nComedy Meet...                   0
# 31  Chris Evans back on the market\n\nBroadcaster ...                   1
# 32  Beastie Boys win sampling battle\n\nUS rappers...                   1
# 33  Lit Idol begins search for author\n\nThe secon...                   1
# 34  No charges against TV's Cosby\n\nUS comedian B...                   1
# 35  US 'to raise TV indecency fines'\n\nUS politic...                   0
# 36  Bangkok film festival battles on\n\nOrganisers...                   0
# 37  Spark heads world Booker list\n\nDame Muriel S...                   1
# 38  Gallery unveils interactive tree\n\nA Christma...                   1
# 39  Michael film signals 'retirement'\n\nSinger Ge...                   0
# 40  Glasgow hosts tsunami benefit gig\n\nThe top n...                   0
# 41  Roundabout continues nostalgia trip\n\nThe new...                   1
# 42  Original Exorcist to be screened\n\nThe origin...                   0
# 43  Horror film heads US box office\n\nA low-budge...                   1
# 44  Last Star Wars 'not for children'\n\nThe sixth...                   0
# 45  US box office set for record high\n\nTicket sa...                   1
# 46  Corbett attacks 'dumbed-down TV'\n\nRonnie Cor...                   0
#
#                                             summaries  summary_sentiment  \
# 0   Ipod owners can now download the Band Aid sing...                  0
# 1   "The other nominees said they made their films...                  1
# 2   Pop star Britney Spears has attacked "false" a...                  1
# 3   Although she grossed more than Prince last yea...                  0
# 4   The producers behind the Lord of the Rings mus...                  0
# 5   Although she grossed more than Prince last yea...                  0
# 6   Animated movie Robots has opened at the top of...                  0
# 7   The head of Christian Brothers' school St Fint...                  0
# 8   Record producer Terry Melcher, who was behind ...                  0
# 9   Janie Hendrix, the guitarist's stepsister, sai...                  1
# 10  "Bobby Darin was one of the greatest entertain...                  1
# 11  The only people who will know the Oscar winner...                  0
# 12  In a separate case relating to the same incide...                  1
# 13  Snow Patrol had "no other course of action" bu...                  1
# 14  Five other episodes of the show had also been ...                  1
# 15  He then wrote Ring of Fire with June Carter Ca...                  1
# 16  Premiership footballer and record company boss...                  1
# 17  A spokeswoman for the RAD said: "It is our res...                  1
# 18  While he said the Oscar voting panel were not ...                  1
# 19  It was bought by a London dealer who sold it o...                  1
# 20  Babyshambles, which he formed after his acrimo...                  1
# 21  A film based on the internet musings of the "B...                  1
# 22  Rapper 50 Cent has ended his public feud with ...                  1
# 23  Green Day, the Foo Fighters and Keane are amon...                  0
# 24  The last film to be made by the slain Dutch di...                  1
# 25  A Fool Such As I would become the 1,001st numb...                  0
# 26  Davis, who was married to actress Ruby Dee, wa...                  1
# 27  The films look well transferred to DVD, though...                  1
# 28  Scoggins was best remembered for singing the t...                  0
# 29  Talk show host Jerry Springer, whose programme...                  0
# 30  Meet the Fockers also broke the box office rec...                  1
# 31  The prices were steep by a lot of people's sta...                  0
# 32  Mr Newton and the Beastie Boys were not availa...                  0
# 33  Writer Tony Cowell is among the judges who wil...                  0
# 34  Cosby's lawyer, Walter M Phillips Jr, said the...                  0
# 35  Last year's Janet Jackson 'wardrobe malfunctio...                  1
# 36  Organisers of the third Bangkok International ...                  1
# 37  Dame Muriel Spark is among three British autho...                  0
# 38  The messages will be "unwrapped" by sculptor R...                  0
# 39  "I thought I should explain myself before I di...                  1
# 40  Colin MacIntyre, of Mull Historical Society, w...                  1
# 41  One puppet show that I personally would love t...                  0
# 42  Schrader was replaced by director Renny Harlin...                  1
# 43  This year, the top 12 films grossed around $91...                  0
# 44  Lucas predicted the film would get a US rating...                  1
# 45  Sony Pictures, responsible for hits like Spide...                  0
# 46  Speaking to the Radio Times, the Two Ronnies s...                  1
#
#                                       pred_summary_pt  pred_summary_sentiment
# 0   Ipod owners can now download the Band Aid sing...                       1
# 1   Arnold's gritty drama Wasp is about a single m...                       0
# 2   Pop star Britney Spears has attacked "false" a...                       1
# 3   The singer banked $56.5m (£30.4m) from concert...                       1
# 4   The producers behind the Lord of the Rings mus...                       1
# 5   The singer banked $56.5m (£30.4m) from concert...                       1
# 6   Meanwhile, Will Smith comedy Hitch has become ...                       0
# 7   The head of Christian Brothers' school St Fint...                       0
# 8   Record producer Terry Melcher, who was behind ...                       0
# 9   Now Mr Goldman is calling for the authority to...                       0
# 10  "I knew absolutely nothing about Bobby Darin b...                       0
# 11  The race for the Oscars entered its final stag...                       0
# 12  In a separate case relating to the same incide...                       1
# 13  Mark McClelland had been in the band for more ...                       0
# 14  The head of US TV network Fox has admitted the...                       0
# 15  Merle Kilgore, co-writer of the country hit Ri...                       0
# 16  Premiership footballer and record company boss...                       1
# 17  Ms Trew, who runs a dance school in Gateshead,...                       0
# 18  Moore's caustic documentary may have been affe...                       1
# 19  Portrait of Omai fetched the second highest am...                       0
# 20  Babyshambles played for 5,000 fans at London's...                       0
# 21  A film based on the internet musings of the "B...                       1
# 22  The Boys Choir of Harlem got a cheque for $150...                       0
# 23  Tickets for Scotland's biggest music festival ...                       0
# 24  Van Gogh's movie mixes real images of the day ...                       0
# 25  A Fool Such As I would become the 1,001st numb...                       0
# 26  Davis, who was married to actress Ruby Dee, wa...                       1
# 27  It's a universal rule that a film can either b...                       1
# 28  Scoggins was best remembered for singing the t...                       1
# 29  Talk show host Jerry Springer, whose programme...                       0
# 30  It took $42.8m (£23.7m) at the weekend, making...                       0
# 31  Broadcaster Chris Evans has begun selling thou...                       0
# 32  US rappers Beastie Boys have won their long-ru...                       1
# 33  The second Pop Idol-style search for literary ...                       1
# 34  Authorities in Philadelphia said they found in...                       1
# 35  US politicians are proposing a tough new law a...                       1
# 36  Organisers of the third Bangkok International ...                       0
# 37  McEwan and Margaret Atwood are the only nomine...                       0
# 38  A Christmas tree that can receive text message...                       1
# 39  Singer George Michael has said that a new film...                       1
# 40  Colin MacIntyre, of Mull Historical Society, w...                       1
# 41  The new big-screen version of The Magic Rounda...                       1
# 42  The film, directed by Paul Schrader, will be s...                       1
# 43  Boogeyman, which cost just $7m (£3.5m) to make...                       0
# 44  He said he expected the film would be classifi...                       1
# 45  Horror movie The Grudge cost Sony $10 million ...                       1
# 46  Corbett said he and Barker were always mindful...                       1

# %%
results_sentiment = results.loc[(results['articles_sentiment'] == results['pred_summary_sentiment'])]

# %%
print(test_df_entertainment.shape)
print(results_sentiment.shape)
# Out:
# (47, 6)
# (24, 6)

# %% [markdown]
# ## **Similarity**

# %%
# !pip install --upgrade spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)

# %%
import spacy.cli
spacy.cli.download("en_core_web_lg")
nlp = spacy.load("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
from numpy import unicode
# Out:
# <ipython-input-14-03ba566f0dcf>:1: DeprecationWarning: `np.unicode` is a deprecated alias for `np.compat.unicode`. To silence this warning, use `np.compat.unicode` by itself. In the likely event your code does not need to work on Python 2 you can use the builtin `str` for which `np.compat.unicode` is itself an alias. Doing this will not modify any behaviour and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from numpy import unicode

# %%
def find_sim(doc1, doc2):
  doc1 = nlp(unicode(doc1))
  doc2 = nlp(unicode(doc2))
  return doc1.similarity(doc2)

# %%
results['similarity'] = 0

# %%
results['similarity'] = results.apply(lambda x: find_sim(x['summaries'], x['pred_summary_pt']), axis=1)

# %%
results
# Out:
#                                              articles  articles_sentiment  \
# 0   iTunes now selling Band Aid song\n\nIpod owner...                   1
# 1   Briton wins short film Oscar\n\nThree of the f...                   0
# 2   Britney attacks 'false tabloids'\n\nPop star B...                   0
# 3   Prince crowned 'top music earner'\n\nPrince ea...                   1
# 4   No UK premiere for Rings musical\n\nThe produc...                   1
# 5   Prince crowned 'top music earner'\n\nPrince ea...                   1
# 6   Robots march to US cinema summit\n\nAnimated m...                   1
# 7   Label withdraws McFadden's video\n\nThe new vi...                   1
# 8   Byrds producer Melcher dies at 62\n\nRecord pr...                   1
# 9   Row threatens Hendrix museum plan\n\nProposals...                   0
# 10  UK debut for Kevin Spacey movie\n\nHollywood s...                   0
# 11  Oscars race enters final furlong\n\nThe race f...                   1
# 12  No jail for singer Courtney Love\n\nSinger Cou...                   0
# 13  Snow Patrol bassist exits group\n\nSnow Patrol...                   0
# 14  Fox 'too reliant on reality TV'\n\nThe head of...                   0
# 15  Ring of Fire hit co-writer dies\n\nMerle Kilgo...                   0
# 16  Court halts Mark Morrison album\n\nPremiership...                   0
# 17  Fears raised over ballet future\n\nFewer child...                   0
# 18  Oscars steer clear of controversy\n\nThe Oscar...                   0
# 19  Public show for Reynolds portrait\n\nSir Joshu...                   0
# 20  Rocker Doherty in on-stage fight\n\nRock singe...                   0
# 21  Baghdad Blogger on big screen\n\nA film based ...                   0
# 22  Rapper 50 Cent ends protege feud\n\nRapper 50 ...                   0
# 23  T in the Park sells out in days\n\nTickets for...                   1
# 24  Dutch watch Van Gogh's last film\n\nThe last f...                   0
# 25  Elvis 'set for chart hat-trick'\n\nThe late US...                   1
# 26  US actor Ossie Davis found dead\n\nUS actor Os...                   0
# 27  DVD review: Spider-Man 2\n\nIt's a universal r...                   0
# 28  Hillbillies singer Scoggins dies\n\nCountry an...                   1
# 29  Springer criticises Opera musical\n\nTalk show...                   1
# 30  Fockers retain film chart crown\n\nComedy Meet...                   0
# 31  Chris Evans back on the market\n\nBroadcaster ...                   1
# 32  Beastie Boys win sampling battle\n\nUS rappers...                   1
# 33  Lit Idol begins search for author\n\nThe secon...                   1
# 34  No charges against TV's Cosby\n\nUS comedian B...                   1
# 35  US 'to raise TV indecency fines'\n\nUS politic...                   0
# 36  Bangkok film festival battles on\n\nOrganisers...                   0
# 37  Spark heads world Booker list\n\nDame Muriel S...                   1
# 38  Gallery unveils interactive tree\n\nA Christma...                   1
# 39  Michael film signals 'retirement'\n\nSinger Ge...                   0
# 40  Glasgow hosts tsunami benefit gig\n\nThe top n...                   0
# 41  Roundabout continues nostalgia trip\n\nThe new...                   1
# 42  Original Exorcist to be screened\n\nThe origin...                   0
# 43  Horror film heads US box office\n\nA low-budge...                   1
# 44  Last Star Wars 'not for children'\n\nThe sixth...                   0
# 45  US box office set for record high\n\nTicket sa...                   1
# 46  Corbett attacks 'dumbed-down TV'\n\nRonnie Cor...                   0
#
#                                             summaries  summary_sentiment  \
# 0   Ipod owners can now download the Band Aid sing...                  0
# 1   "The other nominees said they made their films...                  1
# 2   Pop star Britney Spears has attacked "false" a...                  1
# 3   Although she grossed more than Prince last yea...                  0
# 4   The producers behind the Lord of the Rings mus...                  0
# 5   Although she grossed more than Prince last yea...                  0
# 6   Animated movie Robots has opened at the top of...                  0
# 7   The head of Christian Brothers' school St Fint...                  0
# 8   Record producer Terry Melcher, who was behind ...                  0
# 9   Janie Hendrix, the guitarist's stepsister, sai...                  1
# 10  "Bobby Darin was one of the greatest entertain...                  1
# 11  The only people who will know the Oscar winner...                  0
# 12  In a separate case relating to the same incide...                  1
# 13  Snow Patrol had "no other course of action" bu...                  1
# 14  Five other episodes of the show had also been ...                  1
# 15  He then wrote Ring of Fire with June Carter Ca...                  1
# 16  Premiership footballer and record company boss...                  1
# 17  A spokeswoman for the RAD said: "It is our res...                  1
# 18  While he said the Oscar voting panel were not ...                  1
# 19  It was bought by a London dealer who sold it o...                  1
# 20  Babyshambles, which he formed after his acrimo...                  1
# 21  A film based on the internet musings of the "B...                  1
# 22  Rapper 50 Cent has ended his public feud with ...                  1
# 23  Green Day, the Foo Fighters and Keane are amon...                  0
# 24  The last film to be made by the slain Dutch di...                  1
# 25  A Fool Such As I would become the 1,001st numb...                  0
# 26  Davis, who was married to actress Ruby Dee, wa...                  1
# 27  The films look well transferred to DVD, though...                  1
# 28  Scoggins was best remembered for singing the t...                  0
# 29  Talk show host Jerry Springer, whose programme...                  0
# 30  Meet the Fockers also broke the box office rec...                  1
# 31  The prices were steep by a lot of people's sta...                  0
# 32  Mr Newton and the Beastie Boys were not availa...                  0
# 33  Writer Tony Cowell is among the judges who wil...                  0
# 34  Cosby's lawyer, Walter M Phillips Jr, said the...                  0
# 35  Last year's Janet Jackson 'wardrobe malfunctio...                  1
# 36  Organisers of the third Bangkok International ...                  1
# 37  Dame Muriel Spark is among three British autho...                  0
# 38  The messages will be "unwrapped" by sculptor R...                  0
# 39  "I thought I should explain myself before I di...                  1
# 40  Colin MacIntyre, of Mull Historical Society, w...                  1
# 41  One puppet show that I personally would love t...                  0
# 42  Schrader was replaced by director Renny Harlin...                  1
# 43  This year, the top 12 films grossed around $91...                  0
# 44  Lucas predicted the film would get a US rating...                  1
# 45  Sony Pictures, responsible for hits like Spide...                  0
# 46  Speaking to the Radio Times, the Two Ronnies s...                  1
#
#                                       pred_summary_pt  pred_summary_sentiment  \
# 0   Ipod owners can now download the Band Aid sing...                       1
# 1   Arnold's gritty drama Wasp is about a single m...                       0
# 2   Pop star Britney Spears has attacked "false" a...                       1
# 3   The singer banked $56.5m (£30.4m) from concert...                       1
# 4   The producers behind the Lord of the Rings mus...                       1
# 5   The singer banked $56.5m (£30.4m) from concert...                       1
# 6   Meanwhile, Will Smith comedy Hitch has become ...                       0
# 7   The head of Christian Brothers' school St Fint...                       0
# 8   Record producer Terry Melcher, who was behind ...                       0
# 9   Now Mr Goldman is calling for the authority to...                       0
# 10  "I knew absolutely nothing about Bobby Darin b...                       0
# 11  The race for the Oscars entered its final stag...                       0
# 12  In a separate case relating to the same incide...                       1
# 13  Mark McClelland had been in the band for more ...                       0
# 14  The head of US TV network Fox has admitted the...                       0
# 15  Merle Kilgore, co-writer of the country hit Ri...                       0
# 16  Premiership footballer and record company boss...                       1
# 17  Ms Trew, who runs a dance school in Gateshead,...                       0
# 18  Moore's caustic documentary may have been affe...                       1
# 19  Portrait of Omai fetched the second highest am...                       0
# 20  Babyshambles played for 5,000 fans at London's...                       0
# 21  A film based on the internet musings of the "B...                       1
# 22  The Boys Choir of Harlem got a cheque for $150...                       0
# 23  Tickets for Scotland's biggest music festival ...                       0
# 24  Van Gogh's movie mixes real images of the day ...                       0
# 25  A Fool Such As I would become the 1,001st numb...                       0
# 26  Davis, who was married to actress Ruby Dee, wa...                       1
# 27  It's a universal rule that a film can either b...                       1
# 28  Scoggins was best remembered for singing the t...                       1
# 29  Talk show host Jerry Springer, whose programme...                       0
# 30  It took $42.8m (£23.7m) at the weekend, making...                       0
# 31  Broadcaster Chris Evans has begun selling thou...                       0
# 32  US rappers Beastie Boys have won their long-ru...                       1
# 33  The second Pop Idol-style search for literary ...                       1
# 34  Authorities in Philadelphia said they found in...                       1
# 35  US politicians are proposing a tough new law a...                       1
# 36  Organisers of the third Bangkok International ...                       0
# 37  McEwan and Margaret Atwood are the only nomine...                       0
# 38  A Christmas tree that can receive text message...                       1
# 39  Singer George Michael has said that a new film...                       1
# 40  Colin MacIntyre, of Mull Historical Society, w...                       1
# 41  The new big-screen version of The Magic Rounda...                       1
# 42  The film, directed by Paul Schrader, will be s...                       1
# 43  Boogeyman, which cost just $7m (£3.5m) to make...                       0
# 44  He said he expected the film would be classifi...                       1
# 45  Horror movie The Grudge cost Sony $10 million ...                       1
# 46  Corbett said he and Barker were always mindful...                       1
#
#     similarity
# 0     0.981875
# 1     0.971488
# 2     0.981679
# 3     0.973905
# 4     0.976453
# 5     0.973905
# 6     0.945105
# 7     0.983255
# 8     0.958508
# 9     0.978913
# 10    0.987825
# 11    0.948897
# 12    0.972071
# 13    0.990722
# 14    0.946100
# 15    0.983868
# 16    0.982529
# 17    0.967030
# 18    0.981523
# 19    0.957652
# 20    0.970651
# 21    0.990007
# 22    0.949669
# 23    0.988714
# 24    0.993773
# 25    1.000000
# 26    0.983931
# 27    0.959018
# 28    0.976206
# 29    0.988442
# 30    0.898629
# 31    0.967941
# 32    0.978806
# 33    0.933414
# 34    0.973154
# 35    0.950334
# 36    0.979473
# 37    0.438894
# 38    0.984110
# 39    0.969279
# 40    0.960854
# 41    0.913859
# 42    0.984931
# 43    0.947047
# 44    0.967989
# 45    0.939997
# 46    0.968694

# %%
results.to_csv('/content/gdrive/My Drive/MIProject/T5model/with_similarity.csv')
